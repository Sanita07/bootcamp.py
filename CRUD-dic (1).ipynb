# %%
# Create a\ dictionary
students = {}
n = int(input("Enter number of students: "))
for i in range(n):
    name = input("Enter name: ")
    marks = int(input("Enter marks: "))
    students[name]=marks
print(students)
Employee={}
p = int(input("Enter no of emp names: "))
for j in range(p):
    emp = input("Enter name: ")
    sal = int(input("Enter sal: "))
    Employee[emp]=sal
print(Employee)
# Read a dictionary
sp=input("Enter  specified emp name :")
if sp in Employee:
    print("Salary:",Employee[emp])
else:
    print("Employee not found:")
# Updating in Dictionary
student_name=input("Enter a student name thet u want to update marks:")
if student_name in students:
    new_marks=int(input("Enter new marks:"))
    students[student_name]=new_marks
    print(students)
else:
    print("Not Found")
# Deleting  specified in Dictionary
del_name=input("Enter a student name thet u want to delete marks:")
if del_name in students:
    del students[del_name]
    print(students)
else:
    print("Not found")
# Deleting in Dictionary
print(students)
students.clear()
print(students)
# Out:
# Enter number of students:  2
# Enter name:  a
# Enter marks:  10
# Enter name:  b
# Enter marks:  20
# {'a': 10, 'b': 20}
# Enter no of emp names:  2
# Enter name:  p
# Enter sal:  100
# Enter name:  q
# Enter sal:  200
# {'p': 100, 'q': 200}
# Enter emp name : q
# Salary: 200
# Enter a student name thet u want to update marks: a
# Enter new marks: 15
# {'a': 15, 'b': 20}
# Enter a student name thet u want to delete marks: b
# {'a': 15}
# {'a': 15}
# {}
